# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroMesquitaIsidoro/Filmes/blob/main/2022/Filmes_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Filmes-2022.csv')

# %%
df
# Out:
#      Ano                                Filme  \
# 0   2014                    Relatos Selvagens
# 1   2010             O Segredo dos Seus Olhos
# 2   2022                           The Batman
# 3   2015        Sicario: Terra de Ninguém\r\n
# 4   1975                        Um Dia de Cão
# 5   1976                          Taxi Driver
# 6   2022                    Top Gun: Maverick
# 7   2015  Ex_Machina: Instinto Artificial\r\n
# 8   2000                             Náufrago
# 9   1997                        Boogie Nights
# 10  1982                 O Rei da Comédia\r\n
# 11  1980                      O Iluminado\r\n
# 12  1980                      Touro Indomável
# 13  1991  JFK - A Pergunta Que Não Quer Calar
# 14  2022    Pinóquio por Guillermo del Toro\r
# 15  1995                              Cassino
# 16  1990         A Caçada ao Outubro Vermelho
# 17  2007                       A Garota Ideal
# 18  1978        Halloween - A Noite do Terror
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ano      37 non-null     int64
#  1   Filme    37 non-null     object
#  2   Diretor  37 non-null     object
#  3   Nota     37 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.3+ KB

# %%
print('O dataset possui',df.shape[0], 'linhas(filmes) e', df.shape[1], 'atributos.')
# Out:
# O dataset possui 37 linhas(filmes) e 4 atributos.

# %%
df.describe()
# Out:
#                Ano       Nota
# count    37.000000  37.000000
# mean   2003.540541   7.843243
# std      16.958437   0.633570
# min    1973.000000   6.400000
# 25%    1990.000000   7.500000
# 50%    2007.000000   8.000000
# 75%    2022.000000   8.400000
# max    2022.000000   8.700000

# %%
df['Diretor'].value_counts()
# Out:
# Martin Scorsese                        4
# Robert Eggers                          2
# Sidney Lumet                           2
# Damián Szifron                         1
# Baz Luhrmann                           1
# Darren Aronofsky                       1
# Aaron Sorkin                           1
# John Krasinski                         1
# Andrew Davis                           1
# Rob Reiner                             1
# Scott Mann                             1
# Kyle Balda                             1
# Tony Scott                             1
# Andrew Niccol                          1
# Ruben Fleischer                        1
# Taika Waititi                          1
# Taylor Hackford                        1
# James Cameron                          1
# Juan José Campanella                   1
# John Carpenter                         1
# Craig Gillespie                        1
# John McTiernan                         1
# Guillermo del Toro e Mark Gustafson    1
# ...

# %%
df['Diretor'].value_counts()[:32].plot(kind='barh', legend = '', color = 'green',
                                       title = 'Diretores mais assistidos em 2022')
plt.show()

# %%
df['Ano'].value_counts()[:30].plot(kind='barh', legend = '', color = 'blue',
                                       title = 'Anos que mais assisti em 2022')
plt.show()
